# %%
import requests
from pprint import pprint
import base64
import os
import re
import random
import IPython

# %% [markdown]
# Before you can use the spotify api, you need to create a developers account at spotify.
# [Make a spotify app here](https://developer.spotify.com/my-applications/#!/applications)
#
# They will give your application two tokens. A client id and a secret token. Those should be passed as a string to the two parameters below.

# %%
# The tokens needed for the spotify web api.
_id = ""
_secret = ""

# The root directory to save your music previews.
save_loc = r"/media/ritchie46/5E061D60061D3A8B/dataset/mp3"

# The desired genres

genres = ["jazz", "rnb", "rock", "edm_dance", "hiphop", "classical", "funk"]

# %%
class Connection:
    """
    Class' object instantiates a connection with spotify. When the connection is alive, queries are made with the query_get
    method.
    """
    def __init__(self, client_id, secret):
        # First header and parameters needed to require an access token.
        param = {"grant_type": "client_credentials"}
        header = {"Authorization": "Basic {}".format(
            base64.b64encode("{}:{}".format(client_id, secret).encode("ascii")).decode("ascii")),
                  'Content-Type': 'application/x-www-form-urlencoded'}
        self.token = requests.post("https://accounts.spotify.com/api/token", param, headers=header).json()["access_token"]
        self.header = {"Authorization": "Bearer {}".format(self.token)}
        self.base_url = "https://api.spotify.com"

    def query_get(self, query, params=None):
        """
        
        :param query: (str) URL coming after example.com
        :param params: (dict)
        :return: (json) 
        """
        return requests.get(self.base_url + query, params, headers=self.header).json()

# %%
conn = Connection(_id, _secret)

for genre in genres:

    # get genres playlists
    r = conn.query_get('/v1/browse/categories/{}/playlists'.format(genre), {"limit": 50, "offset": 0})
    playlist_ids = [item["id"] for item in r["playlists"]["items"]]
    n = 500
    for i in range(len(playlist_ids)):
        print("running id", _id)
        next_ = True
        offset = 0
        c = 0
        
        while next_ is not None and c < 10:  # count is limited because it will iterate over the same playlists
            print("Next query of the same playlist", next_)

            r = conn.query_get('/v1/users/spotify/playlists/' + playlist_ids[i], {"offset": offset, "limit": n})
            try:
                next_ = r["tracks"]["next"]
                tracks = r["tracks"]["items"]
            except KeyError:
                pprint(r)
            for j in range(len(tracks)):
                name = tracks[j]["track"]["name"]
                name = re.sub("\W", "_", name)
                artist = tracks[j]["track"]["artists"][0]["name"]
                artist = re.sub("\W", "_", artist)
                url = tracks[j]["track"]["preview_url"]
                if url:
                    os.makedirs(os.path.join(save_loc, genre), exist_ok=True)
                    f = os.path.join(save_loc, genre, "{}-{}.mp3".format(artist, name))

                    if not os.path.isfile(f):
                        r = requests.get(url)
                        print("Saving {}-{}.mp3".format(artist, name))
                        with open(f, "wb") as f:
                            f.write(r.content)
                    else:
                        print("file already exists")
                else:
                    print("could not find url for {}-{}.mp3".format(artist, name))
            offset += n
            c += 1
# Out:
# running id 118f1dbd33134159aa1089eeed003e4d
# Next query of the same playlist True
# Saving David_Hazeltine-I_ll_Let_You_Know.mp3
# Saving John_Coltrane-I_ll_Wait_And_Pray.mp3
# Saving Scott_Hamilton-The_Shadow_of_Your_Smile.mp3
# Saving Trio_X_of_Sweden-Vid_Frösö_kyrka__At_Frösö_Church____From_Frösöblomster__Frösö_Flowers___arr__J__Ekberg__P_V__Johansson_and_L__Simonsson_.mp3
# could not find url for Terence_Blanchard-Jackie_Gets_Out.mp3
# Saving Shilts-Outside_the_Box.mp3
# Saving Randy_Scott-Copacetic.mp3
# could not find url for Andrew_Neu-Everything_Happens_for_a_Reason.mp3
# Saving Michael_Lington-Off_The_Hook.mp3
# Saving Paul_Taylor-Prime_Time.mp3
# Saving Terje_Lie-Crazy_Groove.mp3
# Saving André_Ward-City_Vibe.mp3
# Saving Richard_Elliot-Chill_Factor.mp3
# Saving Jessy_J-Una_Mas.mp3
# Saving Mindi_Abair-Down_for_the_Count.mp3
# Saving Rocco_Ventrella-She_s_Ready.mp3
# Saving Eric_Darius-Retro_Forward.mp3
# Saving Darren_Rahn-Tale_of_Two_Cities.mp3
# Saving David_Sanborn-Rikke.mp3
# Saving Boney_James-futuresoul.mp3
# Saving BWB-Another_Part_of_Me.mp3
# Saving Nelson_Rangell-City_Lights.mp3
# could not find url for Everette_Harp-All_Jazzed_Up__And_Nowhere_To_Go_.mp3
# could not find url for Pamela_Williams-Frobidden_Fruit.mp3
# could not find url for The_Sax_Pack-The_Sax_Pack.mp3
# Saving Warren_Hill-Skinny_Dippin_.mp3
# Saving Boney_James-Stone_Groove.mp3
# Saving Walter_Beasley-Hard_Work__feat__Michael_O_Hara_.mp3
# Saving Player_A-Sleekness__feat__Marcus_Anderson_.mp3
# Saving Will_Donato-Laws_Of_Attraction.mp3
# Saving George_Howard-Luv_N__Haight.mp3
# Saving Vincent_Ingala-Groovin__U__feat__Gregg_Karukas_.mp3
# Saving Grady_Nichols-Livin__The_Life.mp3
# could not find url for Jeff_Kashiwa-The_Lucky_One.mp3
# Saving Brad_Rambur-Warm___Album_Mix.mp3
# Saving Bobby_Ricketts-A_Song_For_You.mp3
# running id 118f1dbd33134159aa1089eeed003e4d
# Next query of the same playlist True
# Saving Esbjörn_Svensson_Trio-Where_We_Used_To_Live.mp3
# could not find url for Wes_Montgomery-In_Your_Own_Sweet_Way.mp3
# could not find url for Ben_Webster-I_Didn_t_Know_About_You.mp3
# Saving Wynton_Marsalis-When_It_s_Sleepytime_Down_South.mp3
# could not find url for Bill_Evans-Blue_In_Green__Take_3_.mp3
# Saving The_Dave_Brubeck_Quartet-Strange_Meadow_Lark.mp3
# Saving Dexter_Gordon-I_Guess_I_ll_Hang_My_Tears_Out_To_Dry___1999_Digital_Remaster.mp3
# Saving Ben_Webster-Stardust.mp3
# Saving John_Coltrane-Naima.mp3
# could not find url for Chris_Botti-The_Very_Thought_Of_You.mp3
# could not find url for Bengt_Hallberg-So_Long_Blues.mp3
# Saving Miles_Davis-_Round_Midnight.mp3
# could not find url for Bill_Evans_Trio-Young_and_Foolish.mp3
# Saving Scott_Hamilton-Min_Soldat__My_Soldier_.mp3
# could not find url for Thelonious_Monk-Ruby__My_Dear.mp3
# Saving The_Dave_Brubeck_Quartet-Take_Five.mp3
# Saving Stan_Getz-Misty.mp3
# file already exists
# Saving Bobby_Hutcherson-Tranquillity___Digitally_Remastered.mp3
# could not find url for Herbie_Hancock-Alone_and_I.mp3
# could not find url for Vince_Guaraldi_Trio-Charlie_Brown_Theme.mp3
# could not find url for John_Coltrane_Quartet-Africa.mp3
# could not find url for John_Coltrane_Quartet-Greensleeves.mp3
# could not find url for John_Coltrane_Quartet-Blues_Minor.mp3
# could not find url for John_Coltrane_Quartet-You_Don_t_Know_What_Love_Is.mp3
# could not find url for John_Coltrane_Quartet-I_Wish_I_Knew.mp3
# could not find url for John_Coltrane-All_Or_Nothing_At_All___Take_2.mp3
# could not find url for Duke_Ellington-My_Little_Brown_Book.mp3
# could not find url for Duke_Ellington-The_Feeling_Of_Jazz.mp3
# could not find url for John_Coltrane-They_Say_It_s_Wonderful.mp3
# could not find url for John_Coltrane-Dedicated_To_You.mp3
# could not find url for John_Coltrane-My_One_And_Only_Love.mp3
# could not find url for John_Coltrane-You_Are_Too_Beautiful.mp3
# could not find url for John_Coltrane-Autumn_Serenade.mp3
# Next query of the same playlist https://api.spotify.com/v1/users/spotify/playlists/37i9dQZF1DWVx3vT1QCKCV/tracks?offset=500&limit=500
# file already exists
# file already exists
# file already exists
# could not find url for Duke_Ellington-Take_The_Coltrane.mp3
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# could not find url for John_Coltrane-Trane_s_Blues__aka_John_Paul_Jones____Instrumental.mp3
# could not find url for Duke_Ellington-Stevie.mp3
# could not find url for John_Coltrane-Stardust.mp3
# file already exists
# file already exists
# could not find url for Duke_Ellington-Angelica.mp3
# file already exists
# file already exists
# file already exists
# could not find url for John_Coltrane-Blue_Train.mp3
# could not find url for John_Coltrane-Time_After_Time.mp3
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# could not find url for John_Coltrane-Syeeda_s_Song_Flute.mp3
# could not find url for -.mp3
# could not find url for John_Coltrane-On_Green_Dolphin_Street.mp3
# could not find url for -.mp3
# file already exists
# file already exists
# could not find url for John_Coltrane_Quartet-Soul_Eyes.mp3
# file already exists
# could not find url for -.mp3
# could not find url for John_Coltrane-Minor_Mishap.mp3
# could not find url for John_Coltrane-Giant_Steps.mp3
# could not find url for John_Coltrane-How_Long_Has_This_Been_Going_On.mp3
# could not find url for John_Coltrane-Cousin_Mary__alternate_Take_.mp3
# could not find url for John_Coltrane-A_Love_Supreme__Pt__I___Acknowledgement.mp3
# could not find url for John_Coltrane-A_Love_Supreme__Pt__II___Resolution.mp3
# could not find url for John_Coltrane-A_Love_Supreme__Pt__III___Pursuance.mp3
# could not find url for John_Coltrane-A_Love_Supreme__Pt__IV___Psalm.mp3
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# could not find url for John_Coltrane_Quartet-Africa.mp3
# could not find url for John_Coltrane_Quartet-Greensleeves.mp3
# could not find url for John_Coltrane_Quartet-Blues_Minor.mp3
# could not find url for John_Coltrane_Quartet-You_Don_t_Know_What_Love_Is.mp3
# could not find url for John_Coltrane_Quartet-I_Wish_I_Knew.mp3
# could not find url for John_Coltrane-All_Or_Nothing_At_All___Take_2.mp3
# could not find url for Duke_Ellington-My_Little_Brown_Book.mp3
# could not find url for Duke_Ellington-The_Feeling_Of_Jazz.mp3
# could not find url for John_Coltrane-They_Say_It_s_Wonderful.mp3
# could not find url for John_Coltrane-Dedicated_To_You.mp3
# could not find url for John_Coltrane-My_One_And_Only_Love.mp3
# could not find url for John_Coltrane-You_Are_Too_Beautiful.mp3
# could not find url for John_Coltrane-Autumn_Serenade.mp3
# Next query of the same playlist https://api.spotify.com/v1/users/spotify/playlists/37i9dQZF1DWVx3vT1QCKCV/tracks?offset=500&limit=500
# file already exists
# file already exists
# file already exists
# could not find url for Duke_Ellington-Take_The_Coltrane.mp3
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# could not find url for John_Coltrane-Trane_s_Blues__aka_John_Paul_Jones____Instrumental.mp3
# could not find url for Duke_Ellington-Stevie.mp3
# could not find url for John_Coltrane-Stardust.mp3
# file already exists
# file already exists
# could not find url for Duke_Ellington-Angelica.mp3
# file already exists
# file already exists
# file already exists
# could not find url for John_Coltrane-Blue_Train.mp3
# could not find url for John_Coltrane-Time_After_Time.mp3
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# could not find url for John_Coltrane-Syeeda_s_Song_Flute.mp3
# could not find url for -.mp3
# could not find url for John_Coltrane-On_Green_Dolphin_Street.mp3
# could not find url for -.mp3
# file already exists
# file already exists
# could not find url for John_Coltrane_Quartet-Soul_Eyes.mp3
# file already exists
# could not find url for -.mp3
# could not find url for John_Coltrane-Minor_Mishap.mp3
# could not find url for John_Coltrane-Giant_Steps.mp3
# could not find url for John_Coltrane-How_Long_Has_This_Been_Going_On.mp3
# could not find url for John_Coltrane-Cousin_Mary__alternate_Take_.mp3
# could not find url for John_Coltrane-A_Love_Supreme__Pt__I___Acknowledgement.mp3
# could not find url for John_Coltrane-A_Love_Supreme__Pt__II___Resolution.mp3
# could not find url for John_Coltrane-A_Love_Supreme__Pt__III___Pursuance.mp3
# could not find url for John_Coltrane-A_Love_Supreme__Pt__IV___Psalm.mp3
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# could not find url for John_Coltrane_Quartet-Africa.mp3
# could not find url for John_Coltrane_Quartet-Greensleeves.mp3
# could not find url for John_Coltrane_Quartet-Blues_Minor.mp3
# could not find url for John_Coltrane_Quartet-You_Don_t_Know_What_Love_Is.mp3
# could not find url for John_Coltrane_Quartet-I_Wish_I_Knew.mp3
# could not find url for John_Coltrane-All_Or_Nothing_At_All___Take_2.mp3
# could not find url for Duke_Ellington-My_Little_Brown_Book.mp3
# could not find url for Duke_Ellington-The_Feeling_Of_Jazz.mp3
# could not find url for John_Coltrane-They_Say_It_s_Wonderful.mp3
# could not find url for John_Coltrane-Dedicated_To_You.mp3
# could not find url for John_Coltrane-My_One_And_Only_Love.mp3
# could not find url for John_Coltrane-You_Are_Too_Beautiful.mp3
# could not find url for John_Coltrane-Autumn_Serenade.mp3
# Next query of the same playlist https://api.spotify.com/v1/users/spotify/playlists/37i9dQZF1DWVx3vT1QCKCV/tracks?offset=500&limit=500
# file already exists
# file already exists
# file already exists
# could not find url for Duke_Ellington-Take_The_Coltrane.mp3
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# could not find url for John_Coltrane-Trane_s_Blues__aka_John_Paul_Jones____Instrumental.mp3
# could not find url for Duke_Ellington-Stevie.mp3
# could not find url for John_Coltrane-Stardust.mp3
# file already exists
# file already exists
# could not find url for Duke_Ellington-Angelica.mp3
# file already exists
# file already exists
# file already exists
# could not find url for John_Coltrane-Blue_Train.mp3
# could not find url for John_Coltrane-Time_After_Time.mp3
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# could not find url for John_Coltrane-Syeeda_s_Song_Flute.mp3
# could not find url for -.mp3
# could not find url for John_Coltrane-On_Green_Dolphin_Street.mp3
# could not find url for -.mp3
# file already exists
# file already exists
# could not find url for John_Coltrane_Quartet-Soul_Eyes.mp3
# file already exists
# could not find url for -.mp3
# could not find url for John_Coltrane-Minor_Mishap.mp3
# could not find url for John_Coltrane-Giant_Steps.mp3
# could not find url for John_Coltrane-How_Long_Has_This_Been_Going_On.mp3
# could not find url for John_Coltrane-Cousin_Mary__alternate_Take_.mp3
# could not find url for John_Coltrane-A_Love_Supreme__Pt__I___Acknowledgement.mp3
# could not find url for John_Coltrane-A_Love_Supreme__Pt__II___Resolution.mp3
# could not find url for John_Coltrane-A_Love_Supreme__Pt__III___Pursuance.mp3
# could not find url for John_Coltrane-A_Love_Supreme__Pt__IV___Psalm.mp3
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# could not find url for John_Coltrane_Quartet-Africa.mp3
# could not find url for John_Coltrane_Quartet-Greensleeves.mp3
# could not find url for John_Coltrane_Quartet-Blues_Minor.mp3
# could not find url for John_Coltrane_Quartet-You_Don_t_Know_What_Love_Is.mp3
# could not find url for John_Coltrane_Quartet-I_Wish_I_Knew.mp3
# could not find url for John_Coltrane-All_Or_Nothing_At_All___Take_2.mp3
# could not find url for Duke_Ellington-My_Little_Brown_Book.mp3
# could not find url for Duke_Ellington-The_Feeling_Of_Jazz.mp3
# could not find url for John_Coltrane-They_Say_It_s_Wonderful.mp3
# could not find url for John_Coltrane-Dedicated_To_You.mp3
# could not find url for John_Coltrane-My_One_And_Only_Love.mp3
# could not find url for John_Coltrane-You_Are_Too_Beautiful.mp3
# could not find url for John_Coltrane-Autumn_Serenade.mp3
# Next query of the same playlist https://api.spotify.com/v1/users/spotify/playlists/37i9dQZF1DWVx3vT1QCKCV/tracks?offset=500&limit=500
# file already exists
# file already exists
# file already exists
# could not find url for Duke_Ellington-Take_The_Coltrane.mp3
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# could not find url for John_Coltrane-Trane_s_Blues__aka_John_Paul_Jones____Instrumental.mp3
# could not find url for Duke_Ellington-Stevie.mp3
# could not find url for John_Coltrane-Stardust.mp3
# file already exists
# file already exists
# could not find url for Duke_Ellington-Angelica.mp3
# file already exists
# file already exists
# file already exists
# could not find url for John_Coltrane-Blue_Train.mp3
# could not find url for John_Coltrane-Time_After_Time.mp3
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# could not find url for John_Coltrane-Syeeda_s_Song_Flute.mp3
# could not find url for -.mp3
# could not find url for John_Coltrane-On_Green_Dolphin_Street.mp3
# could not find url for -.mp3
# file already exists
# file already exists
# could not find url for John_Coltrane_Quartet-Soul_Eyes.mp3
# file already exists
# could not find url for -.mp3
# could not find url for John_Coltrane-Minor_Mishap.mp3
# could not find url for John_Coltrane-Giant_Steps.mp3
# could not find url for John_Coltrane-How_Long_Has_This_Been_Going_On.mp3
# could not find url for John_Coltrane-Cousin_Mary__alternate_Take_.mp3
# could not find url for John_Coltrane-A_Love_Supreme__Pt__I___Acknowledgement.mp3
# could not find url for John_Coltrane-A_Love_Supreme__Pt__II___Resolution.mp3
# could not find url for John_Coltrane-A_Love_Supreme__Pt__III___Pursuance.mp3
# could not find url for John_Coltrane-A_Love_Supreme__Pt__IV___Psalm.mp3
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# could not find url for John_Coltrane_Quartet-Africa.mp3
# could not find url for John_Coltrane_Quartet-Greensleeves.mp3
# could not find url for John_Coltrane_Quartet-Blues_Minor.mp3
# could not find url for John_Coltrane_Quartet-You_Don_t_Know_What_Love_Is.mp3
# could not find url for John_Coltrane_Quartet-I_Wish_I_Knew.mp3
# could not find url for John_Coltrane-All_Or_Nothing_At_All___Take_2.mp3
# could not find url for Duke_Ellington-My_Little_Brown_Book.mp3
# could not find url for Duke_Ellington-The_Feeling_Of_Jazz.mp3
# could not find url for John_Coltrane-They_Say_It_s_Wonderful.mp3
# could not find url for John_Coltrane-Dedicated_To_You.mp3
# could not find url for John_Coltrane-My_One_And_Only_Love.mp3
# could not find url for John_Coltrane-You_Are_Too_Beautiful.mp3
# could not find url for John_Coltrane-Autumn_Serenade.mp3
# Next query of the same playlist https://api.spotify.com/v1/users/spotify/playlists/37i9dQZF1DWVx3vT1QCKCV/tracks?offset=500&limit=500
# file already exists
# file already exists
# file already exists
# could not find url for Duke_Ellington-Take_The_Coltrane.mp3
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# could not find url for John_Coltrane-Trane_s_Blues__aka_John_Paul_Jones____Instrumental.mp3
# could not find url for Duke_Ellington-Stevie.mp3
# could not find url for John_Coltrane-Stardust.mp3
# file already exists
# file already exists
# could not find url for Duke_Ellington-Angelica.mp3
# file already exists
# file already exists
# file already exists
# could not find url for John_Coltrane-Blue_Train.mp3
# could not find url for John_Coltrane-Time_After_Time.mp3
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# could not find url for John_Coltrane-Syeeda_s_Song_Flute.mp3
# could not find url for -.mp3
# could not find url for John_Coltrane-On_Green_Dolphin_Street.mp3
# could not find url for -.mp3
# file already exists
# file already exists
# could not find url for John_Coltrane_Quartet-Soul_Eyes.mp3
# file already exists
# could not find url for -.mp3
# could not find url for John_Coltrane-Minor_Mishap.mp3
# could not find url for John_Coltrane-Giant_Steps.mp3
# could not find url for John_Coltrane-How_Long_Has_This_Been_Going_On.mp3
# could not find url for John_Coltrane-Cousin_Mary__alternate_Take_.mp3
# could not find url for John_Coltrane-A_Love_Supreme__Pt__I___Acknowledgement.mp3
# could not find url for John_Coltrane-A_Love_Supreme__Pt__II___Resolution.mp3
# could not find url for John_Coltrane-A_Love_Supreme__Pt__III___Pursuance.mp3
# could not find url for John_Coltrane-A_Love_Supreme__Pt__IV___Psalm.mp3
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# could not find url for John_Coltrane_Quartet-Africa.mp3
# could not find url for John_Coltrane_Quartet-Greensleeves.mp3
# could not find url for John_Coltrane_Quartet-Blues_Minor.mp3
# could not find url for John_Coltrane_Quartet-You_Don_t_Know_What_Love_Is.mp3
# could not find url for John_Coltrane_Quartet-I_Wish_I_Knew.mp3
# could not find url for John_Coltrane-All_Or_Nothing_At_All___Take_2.mp3
# could not find url for Duke_Ellington-My_Little_Brown_Book.mp3
# could not find url for Duke_Ellington-The_Feeling_Of_Jazz.mp3
# could not find url for John_Coltrane-They_Say_It_s_Wonderful.mp3
# could not find url for John_Coltrane-Dedicated_To_You.mp3
# could not find url for John_Coltrane-My_One_And_Only_Love.mp3
# could not find url for John_Coltrane-You_Are_Too_Beautiful.mp3
# could not find url for John_Coltrane-Autumn_Serenade.mp3
# Next query of the same playlist https://api.spotify.com/v1/users/spotify/playlists/37i9dQZF1DWVx3vT1QCKCV/tracks?offset=500&limit=500
# file already exists
# file already exists
# file already exists
# could not find url for Duke_Ellington-Take_The_Coltrane.mp3
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# could not find url for John_Coltrane-Trane_s_Blues__aka_John_Paul_Jones____Instrumental.mp3
# could not find url for Duke_Ellington-Stevie.mp3
# could not find url for John_Coltrane-Stardust.mp3
# file already exists
# file already exists
# could not find url for Duke_Ellington-Angelica.mp3
# file already exists
# file already exists
# file already exists
# could not find url for John_Coltrane-Blue_Train.mp3
# could not find url for John_Coltrane-Time_After_Time.mp3
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# could not find url for John_Coltrane-Syeeda_s_Song_Flute.mp3
# could not find url for -.mp3
# could not find url for John_Coltrane-On_Green_Dolphin_Street.mp3
# could not find url for -.mp3
# file already exists
# file already exists
# could not find url for John_Coltrane_Quartet-Soul_Eyes.mp3
# file already exists
# could not find url for -.mp3
# could not find url for John_Coltrane-Minor_Mishap.mp3
# could not find url for John_Coltrane-Giant_Steps.mp3
# could not find url for John_Coltrane-How_Long_Has_This_Been_Going_On.mp3
# could not find url for John_Coltrane-Cousin_Mary__alternate_Take_.mp3
# could not find url for John_Coltrane-A_Love_Supreme__Pt__I___Acknowledgement.mp3
# could not find url for John_Coltrane-A_Love_Supreme__Pt__II___Resolution.mp3
# could not find url for John_Coltrane-A_Love_Supreme__Pt__III___Pursuance.mp3
# could not find url for John_Coltrane-A_Love_Supreme__Pt__IV___Psalm.mp3
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# could not find url for John_Coltrane_Quartet-Africa.mp3
# could not find url for John_Coltrane_Quartet-Greensleeves.mp3
# could not find url for John_Coltrane_Quartet-Blues_Minor.mp3
# could not find url for John_Coltrane_Quartet-You_Don_t_Know_What_Love_Is.mp3
# could not find url for John_Coltrane_Quartet-I_Wish_I_Knew.mp3
# could not find url for John_Coltrane-All_Or_Nothing_At_All___Take_2.mp3
# could not find url for Duke_Ellington-My_Little_Brown_Book.mp3
# could not find url for Duke_Ellington-The_Feeling_Of_Jazz.mp3
# could not find url for John_Coltrane-They_Say_It_s_Wonderful.mp3
# could not find url for John_Coltrane-Dedicated_To_You.mp3
# could not find url for John_Coltrane-My_One_And_Only_Love.mp3
# could not find url for John_Coltrane-You_Are_Too_Beautiful.mp3
# could not find url for John_Coltrane-Autumn_Serenade.mp3
# Next query of the same playlist https://api.spotify.com/v1/users/spotify/playlists/37i9dQZF1DWVx3vT1QCKCV/tracks?offset=500&limit=500
# file already exists
# file already exists
# file already exists
# could not find url for Duke_Ellington-Take_The_Coltrane.mp3
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# could not find url for John_Coltrane-Trane_s_Blues__aka_John_Paul_Jones____Instrumental.mp3
# could not find url for Duke_Ellington-Stevie.mp3
# could not find url for John_Coltrane-Stardust.mp3
# file already exists
# file already exists
# could not find url for Duke_Ellington-Angelica.mp3
# file already exists
# file already exists
# file already exists
# could not find url for John_Coltrane-Blue_Train.mp3
# could not find url for John_Coltrane-Time_After_Time.mp3
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# could not find url for John_Coltrane-Syeeda_s_Song_Flute.mp3
# could not find url for -.mp3
# could not find url for John_Coltrane-On_Green_Dolphin_Street.mp3
# could not find url for -.mp3
# file already exists
# file already exists
# could not find url for John_Coltrane_Quartet-Soul_Eyes.mp3
# file already exists
# could not find url for -.mp3
# could not find url for John_Coltrane-Minor_Mishap.mp3
# could not find url for John_Coltrane-Giant_Steps.mp3
# could not find url for John_Coltrane-How_Long_Has_This_Been_Going_On.mp3
# could not find url for John_Coltrane-Cousin_Mary__alternate_Take_.mp3
# could not find url for John_Coltrane-A_Love_Supreme__Pt__I___Acknowledgement.mp3
# could not find url for John_Coltrane-A_Love_Supreme__Pt__II___Resolution.mp3
# could not find url for John_Coltrane-A_Love_Supreme__Pt__III___Pursuance.mp3
# ...
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# could not find url for John_Coltrane_Quartet-Africa.mp3
# could not find url for John_Coltrane_Quartet-Greensleeves.mp3
# could not find url for John_Coltrane_Quartet-Blues_Minor.mp3
# could not find url for John_Coltrane_Quartet-You_Don_t_Know_What_Love_Is.mp3
# could not find url for John_Coltrane_Quartet-I_Wish_I_Knew.mp3
# could not find url for John_Coltrane-All_Or_Nothing_At_All___Take_2.mp3
# could not find url for Duke_Ellington-My_Little_Brown_Book.mp3
# could not find url for Duke_Ellington-The_Feeling_Of_Jazz.mp3
# could not find url for John_Coltrane-They_Say_It_s_Wonderful.mp3
# could not find url for John_Coltrane-Dedicated_To_You.mp3
# could not find url for John_Coltrane-My_One_And_Only_Love.mp3
# could not find url for John_Coltrane-You_Are_Too_Beautiful.mp3
# could not find url for John_Coltrane-Autumn_Serenade.mp3
# Next query of the same playlist https://api.spotify.com/v1/users/spotify/playlists/37i9dQZF1DWVx3vT1QCKCV/tracks?offset=500&limit=500
# file already exists
# file already exists
# file already exists
# could not find url for Duke_Ellington-Take_The_Coltrane.mp3
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# could not find url for John_Coltrane-Trane_s_Blues__aka_John_Paul_Jones____Instrumental.mp3
# could not find url for Duke_Ellington-Stevie.mp3
# could not find url for John_Coltrane-Stardust.mp3
# file already exists
# file already exists
# could not find url for Duke_Ellington-Angelica.mp3
# file already exists
# file already exists
# file already exists
# could not find url for John_Coltrane-Blue_Train.mp3
# could not find url for John_Coltrane-Time_After_Time.mp3
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# could not find url for John_Coltrane-Syeeda_s_Song_Flute.mp3
# could not find url for -.mp3
# could not find url for John_Coltrane-On_Green_Dolphin_Street.mp3
# could not find url for -.mp3
# file already exists
# file already exists
# could not find url for John_Coltrane_Quartet-Soul_Eyes.mp3
# file already exists
# could not find url for -.mp3
# could not find url for John_Coltrane-Minor_Mishap.mp3
# could not find url for John_Coltrane-Giant_Steps.mp3
# could not find url for John_Coltrane-How_Long_Has_This_Been_Going_On.mp3
# could not find url for John_Coltrane-Cousin_Mary__alternate_Take_.mp3
# could not find url for John_Coltrane-A_Love_Supreme__Pt__I___Acknowledgement.mp3
# could not find url for John_Coltrane-A_Love_Supreme__Pt__II___Resolution.mp3
# could not find url for John_Coltrane-A_Love_Supreme__Pt__III___Pursuance.mp3
# could not find url for John_Coltrane-A_Love_Supreme__Pt__IV___Psalm.mp3
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# could not find url for John_Coltrane_Quartet-Africa.mp3
# could not find url for John_Coltrane_Quartet-Greensleeves.mp3
# could not find url for John_Coltrane_Quartet-Blues_Minor.mp3
# could not find url for John_Coltrane_Quartet-You_Don_t_Know_What_Love_Is.mp3
# could not find url for John_Coltrane_Quartet-I_Wish_I_Knew.mp3
# could not find url for John_Coltrane-All_Or_Nothing_At_All___Take_2.mp3
# could not find url for Duke_Ellington-My_Little_Brown_Book.mp3
# could not find url for Duke_Ellington-The_Feeling_Of_Jazz.mp3
# could not find url for John_Coltrane-They_Say_It_s_Wonderful.mp3
# could not find url for John_Coltrane-Dedicated_To_You.mp3
# could not find url for John_Coltrane-My_One_And_Only_Love.mp3
# could not find url for John_Coltrane-You_Are_Too_Beautiful.mp3
# could not find url for John_Coltrane-Autumn_Serenade.mp3
# Next query of the same playlist https://api.spotify.com/v1/users/spotify/playlists/37i9dQZF1DWVx3vT1QCKCV/tracks?offset=500&limit=500
# file already exists
# file already exists
# file already exists
# could not find url for Duke_Ellington-Take_The_Coltrane.mp3
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# could not find url for John_Coltrane-Trane_s_Blues__aka_John_Paul_Jones____Instrumental.mp3
# could not find url for Duke_Ellington-Stevie.mp3
# could not find url for John_Coltrane-Stardust.mp3
# file already exists
# file already exists
# could not find url for Duke_Ellington-Angelica.mp3
# file already exists
# file already exists
# file already exists
# could not find url for John_Coltrane-Blue_Train.mp3
# could not find url for John_Coltrane-Time_After_Time.mp3
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# could not find url for John_Coltrane-Syeeda_s_Song_Flute.mp3
# could not find url for -.mp3
# could not find url for John_Coltrane-On_Green_Dolphin_Street.mp3
# could not find url for -.mp3
# file already exists
# file already exists
# could not find url for John_Coltrane_Quartet-Soul_Eyes.mp3
# file already exists
# could not find url for -.mp3
# could not find url for John_Coltrane-Minor_Mishap.mp3
# could not find url for John_Coltrane-Giant_Steps.mp3
# could not find url for John_Coltrane-How_Long_Has_This_Been_Going_On.mp3
# could not find url for John_Coltrane-Cousin_Mary__alternate_Take_.mp3
# could not find url for John_Coltrane-A_Love_Supreme__Pt__I___Acknowledgement.mp3
# could not find url for John_Coltrane-A_Love_Supreme__Pt__II___Resolution.mp3
# could not find url for John_Coltrane-A_Love_Supreme__Pt__III___Pursuance.mp3
# could not find url for John_Coltrane-A_Love_Supreme__Pt__IV___Psalm.mp3
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# could not find url for John_Coltrane_Quartet-Africa.mp3
# could not find url for John_Coltrane_Quartet-Greensleeves.mp3
# could not find url for John_Coltrane_Quartet-Blues_Minor.mp3
# could not find url for John_Coltrane_Quartet-You_Don_t_Know_What_Love_Is.mp3
# could not find url for John_Coltrane_Quartet-I_Wish_I_Knew.mp3
# could not find url for John_Coltrane-All_Or_Nothing_At_All___Take_2.mp3
# could not find url for Duke_Ellington-My_Little_Brown_Book.mp3
# could not find url for Duke_Ellington-The_Feeling_Of_Jazz.mp3
# could not find url for John_Coltrane-They_Say_It_s_Wonderful.mp3
# could not find url for John_Coltrane-Dedicated_To_You.mp3
# could not find url for John_Coltrane-My_One_And_Only_Love.mp3
# could not find url for John_Coltrane-You_Are_Too_Beautiful.mp3
# could not find url for John_Coltrane-Autumn_Serenade.mp3
# Next query of the same playlist https://api.spotify.com/v1/users/spotify/playlists/37i9dQZF1DWVx3vT1QCKCV/tracks?offset=500&limit=500
# file already exists
# file already exists
# file already exists
# could not find url for Duke_Ellington-Take_The_Coltrane.mp3
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# could not find url for John_Coltrane-Trane_s_Blues__aka_John_Paul_Jones____Instrumental.mp3
# could not find url for Duke_Ellington-Stevie.mp3
# could not find url for John_Coltrane-Stardust.mp3
# file already exists
# file already exists
# could not find url for Duke_Ellington-Angelica.mp3
# file already exists
# file already exists
# file already exists
# could not find url for John_Coltrane-Blue_Train.mp3
# could not find url for John_Coltrane-Time_After_Time.mp3
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# could not find url for John_Coltrane-Syeeda_s_Song_Flute.mp3
# could not find url for -.mp3
# could not find url for John_Coltrane-On_Green_Dolphin_Street.mp3
# could not find url for -.mp3
# file already exists
# file already exists
# could not find url for John_Coltrane_Quartet-Soul_Eyes.mp3
# file already exists
# could not find url for -.mp3
# could not find url for John_Coltrane-Minor_Mishap.mp3
# could not find url for John_Coltrane-Giant_Steps.mp3
# could not find url for John_Coltrane-How_Long_Has_This_Been_Going_On.mp3
# could not find url for John_Coltrane-Cousin_Mary__alternate_Take_.mp3
# could not find url for John_Coltrane-A_Love_Supreme__Pt__I___Acknowledgement.mp3
# could not find url for John_Coltrane-A_Love_Supreme__Pt__II___Resolution.mp3
# could not find url for John_Coltrane-A_Love_Supreme__Pt__III___Pursuance.mp3
# could not find url for John_Coltrane-A_Love_Supreme__Pt__IV___Psalm.mp3
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# file already exists
# could not find url for John_Coltrane_Quartet-Africa.mp3
# could not find url for John_Coltrane_Quartet-Greensleeves.mp3
# could not find url for John_Coltrane_Quartet-Blues_Minor.mp3
# could not find url for John_Coltrane_Quartet-You_Don_t_Know_What_Love_Is.mp3
# could not find url for John_Coltrane_Quartet-I_Wish_I_Knew.mp3
# could not find url for John_Coltrane-All_Or_Nothing_At_All___Take_2.mp3
# could not find url for Duke_Ellington-My_Little_Brown_Book.mp3
# could not find url for Duke_Ellington-The_Feeling_Of_Jazz.mp3
# could not find url for John_Coltrane-They_Say_It_s_Wonderful.mp3
# could not find url for John_Coltrane-Dedicated_To_You.mp3
# could not find url for John_Coltrane-My_One_And_Only_Love.mp3
# could not find url for John_Coltrane-You_Are_Too_Beautiful.mp3
# could not find url for John_Coltrane-Autumn_Serenade.mp3
# Next query of the same playlist https://api.spotify.com/v1/users/spotify/playlists/37i9dQZF1DWVx3vT1QCKCV/tracks?offset=500&limit=500
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-c1c34d3d0322> in <module>()
#      19             print("Next query of the same playlist", next_)
#      20
# ---> 21             r = conn.query_get('/v1/users/spotify/playlists/' + playlist_ids[i], {"offset": offset, "limit": n})
#      22             try:
#      23                 next_ = r["tracks"]["next"]
#
# <ipython-input-2-40a6cad2a84c> in query_get(self, query, params)
#      21         :return: (json)
#      22         """
# ---> 23         return requests.get(self.base_url + query, params, headers=self.header).json()
#
# /usr/lib/python3/dist-packages/requests/api.py in get(url, params, **kwargs)
#      65
#      66     kwargs.setdefault('allow_redirects', True)
# ---> 67     return request('get', url, params=params, **kwargs)
#      68
#      69
#
# /usr/lib/python3/dist-packages/requests/api.py in request(method, url, **kwargs)
#      51     # cases, and look like a memory leak in others.
#      52     with sessions.Session() as session:
# ---> 53         return session.request(method=method, url=url, **kwargs)
#      54
#      55
#
# /usr/lib/python3/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     466         }
#     467         send_kwargs.update(settings)
# --> 468         resp = self.send(prep, **send_kwargs)
#     469
#     470         return resp
#
# /usr/lib/python3/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     574
#     575         # Send the request
# --> 576         r = adapter.send(request, **kwargs)
#     577
#     578         # Total elapsed time of the request (approximately)
#
# /usr/lib/python3/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     374                     decode_content=False,
#     375                     retries=self.max_retries,
# --> 376                     timeout=timeout
#     377                 )
#     378
#
# /usr/lib/python3/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, **response_kw)
#     558             httplib_response = self._make_request(conn, method, url,
#     559                                                   timeout=timeout_obj,
# --> 560                                                   body=body, headers=headers)
#     561
#     562             # If we're going to release the connection in ``finally:``, then
#
# /usr/lib/python3/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, **httplib_request_kw)
#     344         # Trigger any extra validation we need to do.
#     345         try:
# --> 346             self._validate_conn(conn)
#     347         except (SocketTimeout, BaseSSLError) as e:
#     348             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# /usr/lib/python3/dist-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     785         # Force connect early to allow us to validate the connection.
#     786         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 787             conn.connect()
#     788
#     789         if not conn.is_verified:
#
# /usr/lib/python3/dist-packages/urllib3/connection.py in connect(self)
#     215     def connect(self):
#     216         # Add certificate verification
# --> 217         conn = self._new_conn()
#     218
#     219         resolved_cert_reqs = resolve_cert_reqs(self.cert_reqs)
#
# /usr/lib/python3/dist-packages/urllib3/connection.py in _new_conn(self)
#     135         try:
#     136             conn = connection.create_connection(
# --> 137                 (self.host, self.port), self.timeout, **extra_kw)
#     138
#     139         except SocketTimeout as e:
#
# /usr/lib/python3/dist-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      79             if source_address:
#      80                 sock.bind(source_address)
# ---> 81             sock.connect(sa)
#      82             return sock
#      83
#
# KeyboardInterrupt:

# %% [markdown]
# # 30 seconds disco!
#
# When you have ran above code snippet above, you can enjoy your 30 seconds disco.
#
# ![](https://media.giphy.com/media/7IKOyJ6j9fCUw/giphy.gif)

# %%
genres_d = os.listdir(save_loc)
for _ in range(5):
    genre_current = genres_d[random.randint(0, len(genres_d) - 1)]
    nrs = os.listdir(os.path.join(save_loc, genre_current))
    choice = random.randint(0, len(nrs) - 1)
    a = IPython.display.Audio(os.path.join(save_loc, genre_current, nrs[choice]))
    IPython.display.display(a)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
